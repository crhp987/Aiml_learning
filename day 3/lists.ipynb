# %%
data = [10, 20, 10,30, 20, 40]
data = set(data)
data = list(data)
data.sort()
print(data)
# Out:
# [10, 20, 30, 40]

# %%
data = [10, 20, 10,30, 20, 40]
unique = []
for item in data:
    if item not in unique:
        unique.append(item)
print(unique)
# Out:
# [10, 20, 30, 40]

# %%
num = [10,30,48,59,80,90]
num.reverse()
print(num)
# Out:
# [90, 80, 59, 48, 30, 10]

# %%
nums = [10,30,48,59,80,90]

unique_nums = list(set(nums))
unique_nums.sort()

print("second largest: ",unique_nums)
# Out:
# second largest:  80

# %%
c=[2,1,2] 
def gg(b):
    for i in b:
        for j in i:
            print()
