# %%
#creating a tuple element
numbers = (10, 20, 30)
single = (5)
print(numbers)
# Out:
# (10, 20, 30)

# %%
#accessing a tuple element
t = (100,200,300)
print(t[0])
print(t[-1])
# Out:
# 100
# 300

# %%
data = [10,20,30,40]
print(data[0])
print(data[-1])
print(data[1:4])
# Out:
# 10
# 40
# [20, 30, 40]
