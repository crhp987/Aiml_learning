# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Asha", "Rahul", "Sita", None, "Kiran"],
    "Age": [23, np.nan, 29, 25, None],
    "Salary": [45000, 52000, None, 48000, 51000],
    "City": ["Bangalore", "Mysuru", "Bangalore", "Mysuru", None]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age   Salary       City
# 0   Asha  23.0  45000.0  Bangalore
# 1  Rahul   NaN  52000.0     Mysuru
# 2   Sita  29.0      NaN  Bangalore
# 3   None  25.0  48000.0     Mysuru
# 4  Kiran   NaN  51000.0       None

# %%
#missing values
df.isnull()
# Out:
#     Name    Age  Salary   City
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False    True  False
# 3   True  False   False  False
# 4  False   True   False   True

# %%
#count missing values
df.isnull().sum()
# Out:
# Name      1
# Age       2
# Salary    1
# City      1
# dtype: int64

# %%
#
df.isnull().any()
# Out:
# Name      True
# Age       True
# Salary    True
# City      True
# dtype: bool

# %%
df.dropna()
# Out:
#    Name   Age   Salary       City
# 0  Asha  23.0  45000.0  Bangalore

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.fillna(0)
# Out:
#     Name   Age   Salary       City
# 0   Asha  23.0  45000.0  Bangalore
# 1  Rahul   0.0  52000.0     Mysuru
# 2   Sita  29.0      0.0  Bangalore
# 3      0  25.0  48000.0     Mysuru
# 4  Kiran   0.0  51000.0          0

# %%
df["Age"].fillna(df["Age"].mean(),  inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df["Age"].fillna(df["Age"].mean(),  inplace=true)
#
# NameError: name 'true' is not defined

# %%
df["Salary"].fillna(df["Salary"].median(),  inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df["Salary"].fillna(df["Salary"].median(),  inplace=true)
#
# NameError: name 'true' is not defined

# %%
df.fillna(method="ffill")
df.fillna(method="bfill")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25532\3857985487.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
# C:\Users\User\AppData\Local\Temp\ipykernel_25532\3857985487.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#     Name   Age   Salary       City
# 0   Asha  23.0  45000.0  Bangalore
# 1  Rahul  29.0  52000.0     Mysuru
# 2   Sita  29.0  48000.0  Bangalore
# 3  Kiran  25.0  48000.0     Mysuru
# 4  Kiran   NaN  51000.0       None

# %%
df.replace("unknown", np.nan, inplace=True)
df.replace(-1, np.nan, inplace=True)

# %%
import pandas as pd
import numpy as np

# Read CSV file
df = pd.read_csv("students.csv")

print("Student Data:\n", df)

# -----------------------------
# Average marks per student
# -----------------------------
df["Average"] = df[["Math", "Science", "English"]].mean(axis=1)

# -----------------------------
# Pass/Fail classification
# -----------------------------
def classify(avg):
    if avg >= 50:
        return "Pass"
    else:
        return "Fail"

df["Result"] = df["Average"].apply(classify)

# -----------------------------
# NumPy analysis
# -----------------------------
marks_array = df[["Math", "Science", "English"]].to_numpy()

print("\nNumPy Analysis:")
print("Overall Average:", np.mean(marks_array))
print("Maximum Marks:", np.max(marks_array))
print("Minimum Marks:", np.min(marks_array))

# -----------------------------
# Filtering pass/fail students
# -----------------------------
passed_students = df[df["Result"] == "Pass"]
failed_students = df[df["Result"] == "Fail"]

print("\nPassed Students:\n", passed_students)
print("\nFailed Students:\n", failed_students)

# -----------------------------
# Subject-wise topper
# -----------------------------
subjects = ["Math", "Science", "English"]

print("\nSubject-wise Toppers:")
for subject in subjects:
    topper = df.loc[df[subject].idxmax()]
    print(f"{subject} Topper: {topper['Name']} ({topper[subject]})")

# -----------------------------
# Attendance vs marks analysis
# -----------------------------
correlation = df["Attendance"].corr(df["Average"])

print("\nAttendance vs Average Marks Correlation:", correlation)

# -----------------------------
# Pandas Series example
# -----------------------------
avg_series = pd.Series(df["Average"], name="Average Marks")
print("\nPandas Series (Average Marks):\n", avg_series)

# Final DataFrame
print("\nFinal Data with Derived Columns:\n", df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 5
#       2 import numpy as np
#       4 # Read CSV file
# ----> 5 df = pd.read_csv("students.csv")
#       7 print("Student Data:\n", df)
#       9 # -----------------------------
#      10 # Average marks per student
#      11 # -----------------------------
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'students.csv'
