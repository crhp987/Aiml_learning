# %%
import pandas as pd

#Create Sample Dataset
data = {
    'Car_ID': [1, 2, 3, 4, 5, 6],
    'Transmission': ['Manual', 'Automatic', 'Manual', 'Automatic', 'Manual', 'Automatic'],
    'Color': ['Red', 'Blue', 'Green', 'Red', 'Blue', 'Green']
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
print("-" * 30)

# Manual = 0, Automatic = 1
df['Transmission'] = df['Transmission'].map({'Manual': 0, 'Automatic': 1})

df = pd.get_dummies(df, columns=['Color'], drop_first=True)

print("Encoded DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    Car_ID Transmission  Color
# 0       1       Manual    Red
# 1       2    Automatic   Blue
# 2       3       Manual  Green
# 3       4    Automatic    Red
# 4       5       Manual   Blue
# 5       6    Automatic  Green
# ------------------------------
# Encoded DataFrame:
#    Car_ID  Transmission  Color_Green  Color_Red
# 0       1             0        False       True
# 1       2             1        False      False
# 2       3             0         True      False
# 3       4             1        False       True
# 4       5             0        False      False
# 5       6             1         True      False
