# %%
#Probability of getting 4 on a dice
favorable = 1
total = 6

prob = favorable / total
print("Probability:", prob)
# Out:
# Probability: 0.16666666666666666

# %%
# P(Head on coin1 AND Head on coin2)
P_A = 1/2
P_B = 1/2

prob = P_A * P_B
print("Independent Probability:", prob)
# Out:
# Independent Probability: 0.25
