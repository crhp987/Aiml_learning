# %%
p_heads = 1/2
p_six = 1/6
p_independent = p_heads * p_six

p_first_red = 5/10
p_second_red = 4/9
p_dependent = p_first_red * p_second_red

print("Independent Event (Heads AND 6):", p_independent)
print("Dependent Event (Two Red marbles):", p_dependent)

# Reflection
print("\nWhy denominator changed?")
print("Because after picking first red marble, total marbles reduce from 10 to 9.")
print("So probability changes. The second event depends on the first event.")
# Out:
# Independent Event (Heads AND 6): 0.08333333333333333
# Dependent Event (Two Red marbles): 0.2222222222222222
#
# Why denominator changed?
# Because after picking first red marble, total marbles reduce from 10 to 9.
# So probability changes. The second event depends on the first event.
