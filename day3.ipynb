# %%
inventory = ["Apples", "Bananas", "Carrots", "Dates"]
print("Current inventory:", inventory)
inventory.append("Eggs")
inventory.remove("Bananas")
inventory.sort()
print("Final updated inventory:", inventory)
# Out:
# Current inventory: ['Apples', 'Bananas', 'Carrots', 'Dates']
# Final updated inventory: ['Apples', 'Carrots', 'Dates', 'Eggs']

# %%
temperatures = [22, 24, 25, 28, 30, 29, 27, 26, 24, 22]
first_reading = temperatures[0]
last_reading = temperatures[-1]

afternoon_peak = temperatures[3:6]
last_3_hours = temperatures[-3:]

print(f"Original Readings: {temperatures}")
print(f"First Reading (index 0): {first_reading}")
print(f"Last Reading (index -1): {last_reading}")
print(f"Afternoon Peak [3:6]: {afternoon_peak}")
print(f"Last 3 Hours [-3:]: {last_3_hours}")
# Out:
# Original Readings: [22, 24, 25, 28, 30, 29, 27, 26, 24, 22]
# First Reading (index 0): 22
# Last Reading (index -1): 22
# Afternoon Peak [3:6]: [28, 30, 29]
# Last 3 Hours [-3:]: [26, 24, 22]

# %%
screen_res = (1920, 1080)
print(f"Current Resolution: {screen_res[0]}x{screen_res[1]}")
print("Tuples cannot be modified!")
# Out:
# Current Resolution: 1920x1080
# Tuples cannot be modified!
