# %%
person={"name":"john",
        "age":30,
        "city":"mumbai"
}
print(person["name"])

person["age"]= 22
print(person)

del(person["age"])
print(person)
# Out:
# john
# {'name': 'john', 'age': 22, 'city': 'mumbai'}
# {'name': 'john', 'city': 'mumbai'}

# %%
person={"name":"john",
        "age":30,
        "city":"mumbai"
}
print(person)
# Out:
# {'name': 'john', 'age': 30, 'city': 'mumbai'}

# %%
print(person["name"])
print(person.get("age"))
print(person.get("salary","not available"))
# Out:
# john
# 30
# not available

# %%
person["email"] = "poornima@gmail.com"
print(person)
# Out:
# {'name': 'john', 'age': 30, 'city': 'mumbai', 'email': 'poornima@gmail.com'}

# %%
print(person.keys())
print(person.values())
print(person.items())
# Out:
# dict_keys(['name', 'age', 'city', 'email'])
# dict_values(['john', 30, 'mumbai', 'poornima@gmail.com'])
# dict_items([('name', 'john'), ('age', 30), ('city', 'mumbai'), ('email', 'poornima@gmail.com')])

# %%
marks = {
    "maths":80,
    "science":75,
    "english":90
}
total=sum(marks.values())
average=total/len(marks)

print("total:",total)
print("average:",average)
# Out:
# total: 245
# average: 81.66666666666667
