# %%
import csv

with open("students.csv", "w", newline="")as file:
    writer = csv.writer(file)
    writer.writerow(["ID","name","age","city"])
    writer.writerow([1,"poornima",21,"mysore"])
    writer.writerow([2,"darshi",27,"banglore"])
    writer.writerow([3,"hema",18,"mumbai"])

    print("csv file created successfully")
# Out:
# csv file created successfully

# %%
import csv
with open("students.csv","r")as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['ID', 'name', 'age', 'city']
# ['1', 'poornima', '21', 'mysore']
# ['2', 'darshi', '27', 'banglore']
# ['3', 'hema', '18', 'mumbai']

# %%
import csv
with open("students.csv","r")as file:
    reader = csv.reader(file)
    data = list(reader)

total_rows = len(data)

total_columns = len(data[0])
print("total rows:",total_rows)
print("total columns:",total_columns)
# Out:
# total rows: 4
# total columns: 4

# %%
ages = []
for row in data[1:]:                   #skip reader
    ages.append(int(row[2]))           #age column index = 2
print(ages)
# Out:
# [21, 27, 18]

# %%
import csv
with open("students.csv", "w", newline="")as file:
