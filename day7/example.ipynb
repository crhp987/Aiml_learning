# %%
file = open("data.txt", "w")

file.write("hello,this is my first cretes file handling.\n")
file.write("this is my first internship of comedkares.\n")
file.write("comedkares located in mysore.")

file.close()

print("file created and data written succedsfully.")
# Out:
# file created and data written succedsfully.

# %%
file = open("data.txt", "a")

# %%
file = open("data.txt", "a")
file.write("\nthis line is appended using append mode.")
file.write("\nfile handling is easy.")
file.close()

print("data appended successfully.")
# Out:
# data appended successfully.

# %%
name = input("enter your name:")
course = input("enter your course:")
file = open("data.txt", "a")
file.write(f"\nName: {name}")
file.write(f"\ncourse: {course}")

file.close()
print("user data saved.")
# Out:
# user data saved.

# %%
file = open("data.txt", "a")
lines = file.readlines()
file.close()

print("total numberof lines:",len(lines))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[7], line 2
#       1 file = open("data.txt", "a")
# ----> 2 lines = file.readlines()
#       3 file.close()
#       5 print("total numberof lines:",len(lines))
#
# UnsupportedOperation: not readable
