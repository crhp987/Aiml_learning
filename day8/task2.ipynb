# %%
import numpy as np
data = np.arange(24)

reshaped_data = data.reshape(4, 3, 2)
final_data = np.transpose(reshaped_data, (0, 2, 1))

print("Final Shape:", final_data.shape)
print("Final Array:\n", final_data)
# Out:
# Final Shape: (4, 2, 3)
# Final Array:
#  [[[ 0  2  4]
#   [ 1  3  5]]
#
#  [[ 6  8 10]
#   [ 7  9 11]]
#
#  [[12 14 16]
#   [13 15 17]]
#
#  [[18 20 22]
#   [19 21 23]]]
