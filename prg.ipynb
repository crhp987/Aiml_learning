# %%
a = 10
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a % b)
# Out:
# 30
# -10
# 200
# 0.5
# 10

# %%
name = input("enter your name")
print("Hello",name)
# Out:
# Hello poornima

# %%
name = input("enter your name: ")
city = input("enter your city: ")

print("nice to meet you,", name)
print("you are from", city)
# Out:
# nice to meet you, poornima
# you are from mysore

# %%
a = 10
convert=float(a)
print(convert)
# Out:
# 10.0

# %%
price = "99.4"
amount = len(price)
print(amount)
# Out:
# 4

# %%
name = input("What is your name? ")
current_age = int(input("How old are you? "))
age_2030 = current_age + 4
print(f"Hey {name}, you will be {age_2030} years old in 2030!")
# Out:
# Hey rama, you will be 25 years old in 2030!

# %%
#type casting with user input
x = int(input("enter the number: "))
y = int(input("enter the number: "))

print("sum:",x+y)
# Out:
# sum: 10

# %%
age = 21
text = "age is" + str(age)

print(text)
# Out:
# age is21

# %%
price = float(input("enter product price: "))
quantity = int(input("enter quantity: "))

total = price * quantity
print("total bill",total)
# Out:
# total bill 50.0

# %%
name = input("enter your name: ") 
name = input("enter your age: ")
current_age = int(input("How old are you: "))

convert = int(age)
print(convert)
print(f"Hey {name}) you will be {age_2030} years old in 2030!")
# Out:
# 21
# Hey 21) you will be 25 years old in 2030!

# %%
name =  input("enter your name: ")
current_age = int(input("How old are you: "))
age_in_2030= current_age + 4
print("hey",name)
print("you will be",age_in_2030,"years old")
# Out:
# hey ram
# you will be 26 years old

# %%
total_bill = float(input("Enter the total bill amount: "))
num_people = int(input("How many people are splitting the bill "))
share_per_person = total_bill / num_people
print(f"Total Bill: {total_bill:.2f}")
print(f"Each person pays: {share_per_person:.2f}")
# Out:
# Total Bill: 100.50
# Each person pays: 20.10

# %%
total_bill = float(input("Enter the total bill amount: "))
num_people = int(input("How many people are splitting the bill "))
share_per_person = total_bill / num_people
print("total bill:amount ")
print("each person pays: (share_per_person)")
Print ("Total Bill: [Amount]. Each person pays: [Share]")
# Out:
# total bill:amount
# each person pays: (share_per_person)

# %%
x=input("enter a number")
z=int(x)
if z%2==0:
      print("even")
else:
      print("odd")
# Out:
# odd

# %%
item_name = "Laptop"
quantity = 2
price = 499.99
in_stock = True
print("Item:", item_name, ", Qty:", quantity, ", Price:", price, ", Available:", in_stock)

total_cost = quantity * price
print("Total Cost:", total_cost)
# Out:
# Item: Laptop , Qty: 2 , Price: 499.99 , Available: True
# Total Cost: 999.98

# %%
name = input("enter your name: ") 
name = input("enter your age: ")
current_age = int(input("How old are you: "))

convert = int(age)
print(convert)
print(f"Hey {name}) you will be {age_2030} years old in 2030!")
# Out:
# 21
# Hey 21) you will be 25 years old in 2030!

# %%
total_bill = float(input("Enter the total bill amount: "))
num_people = int(input("How many people are splitting the bill "))
share_per_person = total_bill / num_people
print(f"Total Bill: {total_bill:.2f}")
print(f"Each person pays: {share_per_person:.2f}")
# Out:
# Total Bill: 100.50
# Each person pays: 20.10

# %%
item_name = "Laptop"
quantity = 2
price = 499.99
in_stock = True
print("Item:", item_name, ", Qty:", quantity, ", Price:", price, ", Available:", in_stock)

total_cost = quantity * price
print("Total Cost:", total_cost)
# Out:
# Item: Laptop , Qty: 2 , Price: 499.99 , Available: True
# Total Cost: 999.98
